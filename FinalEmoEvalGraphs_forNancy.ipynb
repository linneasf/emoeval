# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %cd KET_MOA_MEG_new/Output_squared
# Out:
# [Errno 2] No such file or directory: 'KET_MOA_MEG_new/Output_squared'
# /gpfs/gsfs9/users/ETPB-MEGCore/EmoEval/linnea_scripts

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 

KETPLC_Calcarine_timeseries=pd.read_csv('KETPLC_Calcarine_timeseries.csv')
KETPLC_LMidOcc_timeseries=pd.read_csv('KETPLC_LMidOcc_timeseries.csv')
KETPLC_RMidOcc_timeseries=pd.read_csv('KETPLC_RMidOcc_timeseries.csv')
KETPLC_LFus_timeseries=pd.read_csv('KETPLC_LFus_timeseries.csv')
KETPLC_RFus_timeseries=pd.read_csv('KETPLC_RFus_timeseries.csv')

# variables are DX, Sess, and Valence

graph=sns.lineplot(x="time",y="mag",data=KETPLC_Calcarine_timeseries,hue="DX",style="Sess",estimator="mean", ci=95)
ax=graph.axes
ax.set_xlim(0,0.3)
plt.title('Calcarine', fontsize=18)
plt.xlabel('time (s)', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.tick_params(labelsize=13)
#svm = sn.heatmap(df_cm, annot=True,cmap='coolwarm', linecolor='white', linewidths=1)

figure = graph.get_figure()    
figure.savefig('/home/sepeforrestl2/EmoEvalGraphs/1Calcarine_Line_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/Calcarine_Line_KETPLC.eps',format='eps', dpi=1000)
plt.show()
# Out:
# /usr/local/Anaconda/envs/py3.5/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 


KETPLC_LMidOcc_timeseries=pd.read_csv('KETPLC_LMidOcc_timeseries.csv')
graph=sns.lineplot(x="time",y="mag",data=KETPLC_LMidOcc_timeseries,hue="DX",style="Valence",estimator="mean", ci=95)
ax=graph.axes
ax.set_xlim(0,0.3)
plt.title('Left Mid Occipital', fontsize=18)
plt.xlabel('time (s)', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.tick_params(labelsize=13)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LMidOcc_DXValence_Line_KETPLC.png',format='png', dpi=1000)
plt.show()
# Out:
# /usr/local/Anaconda/envs/py3.5/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
graph=sns.lineplot(x="time",y="mag",data=KETPLC_LFus_timeseries,hue="DX",style="Sess",estimator="mean", ci=95)
ax=graph.axes
ax.set_xlim(0,0.3)
plt.title('Left Fusiform')
plt.xlabel('time (s)')
plt.ylabel('Signal')
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LFus_Line_KETPLC.png',format='png', dpi=1000)
plt.show()

# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt 

KETPLC_LFus_timeseries=pd.read_csv('KETPLC_LFus_timeseries.csv')
graph=sns.lineplot(x="time",y="mag",data=KETPLC_LFus_timeseries,hue="Sess",style="Valence",estimator="mean", ci=95)
ax=graph.axes
ax.set_xlim(0,0.3)
plt.title('Left Fusiform',fontsize=18)
plt.xlabel('time (s)', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.tick_params(labelsize=13)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LFus_SessVal_Line_KETPLC.png',format='png', dpi=1000)
plt.show()
# Out:
# /usr/local/Anaconda/envs/py3.5/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
graph=sns.lineplot(x="time",y="mag",data=KETPLC_LMidOcc_timeseries,hue="DX",style="Sess",estimator="mean", ci=95)
ax=graph.axes
ax.set_xlim(0,0.3)
plt.title('Left Mid Occipital')
plt.xlabel('time (s)', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.tick_params(labelsize=13)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LMidOcc_Line_KETPLC.png',format='png', dpi=1000)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd 

KETPLC_RMidOcc_timeseries=pd.read_csv('KETPLC_RMidOcc_timeseries.csv')

graph=sns.lineplot(x="time",y="mag",data=KETPLC_RMidOcc_timeseries,hue="DX",style="Sess",estimator="mean", ci=95)
ax=graph.axes
ax.set_xlim(0,0.3)
plt.title('Right Mid Occipital')
plt.xlabel('time (s)', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.tick_params(labelsize=13)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/RMidOcc_Line_KETPLC.png',format='png', dpi=1000)
plt.show()
# Out:
# /usr/local/Anaconda/envs/py3.5/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd 

KETPLC_RFus_timeseries=pd.read_csv('KETPLC_RFus_timeseries.csv')
graph=sns.lineplot(x="time",y="mag",data=KETPLC_RFus_timeseries,hue="DX",style="Sess",estimator="mean", ci=95)
ax=graph.axes
ax.set_xlim(0,0.3)
plt.title('Right Fusiform',fontsize=18)
plt.xlabel('time (s)', fontsize=14)
plt.ylabel('Signal', fontsize=14)
plt.tick_params(labelsize=13)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/RFus_Line_KETPLC.png',format='png', dpi=1000)
plt.show()
# Out:
# /usr/local/Anaconda/envs/py3.5/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#for PEAK diagnoses by session effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

#x=['Ketamine','Placebo']
#hc=[0.6666, 0.4133]
#mdd=[.6161, 0.7832]
#hc_err=[0.1483, 0.09782]
#mdd_err=[0.1306, 0.08454]
x=['Placebo','Ketamine']
hc=[0.41330,.6666]
mdd=[0.7832,.6161]
hc_err=[0.09782,0.1483]
mdd_err=[0.08454,0.1306]
hc_plt=plt.plot(hc, label="HC",color='orange')
mdd_plt=plt.plot(mdd, label="MDD", color='steelblue')
plt.rcParams["figure.figsize"]=[5,6]
plt.title('Calcarine Peak DX by Session', fontsize='18')
plt.xlabel('Session', fontsize=14, labelpad=None)
plt.ylabel('Peak', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
plt.errorbar(x,hc,yerr=hc_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,mdd,yerr=mdd_err,color='steelblue',capsize=10,markeredgewidth=3)
plt.autoscale()
plt.legend(loc='lower center',frameon=True)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/Calcarine_DX_Sess_Peak_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/Calcarine_DX_Peak.eps',format='eps', dpi=1000)
plt.show()

# %%
#for LATENCY diagnoses by valence effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

x=['Negative','Positive']
hc=[0.1474, 0.1489]
mdd=[0.1467, 0.1438]
hc_err=[0.001884, 0.001691]
mdd_err=[0.001691, 0.00143]
hc_plt=plt.plot(hc, label="HC",color='orange')
mdd_plt=plt.plot(mdd, label="MDD", color='steelblue')
plt.rcParams["figure.figsize"]=[6,5]
plt.title('Left Mid Occipital DX by Valence', fontsize='18')
plt.xlabel('Valence', fontsize=14, labelpad=None)
plt.ylabel('Latency', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
plt.errorbar(x,hc,yerr=hc_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,mdd,yerr=mdd_err,color='steelblue',capsize=10,markeredgewidth=3)
plt.legend(loc='lower center',frameon=True)
plt.autoscale()
plt.tight_layout()
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/LMidOcc_DX_Valence_Latency.eps',format='eps', dpi=1000, bbox_inches = "tight")
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LMidOcc_DX_Valence_Latency_KETPLC.png',format='png', dpi=1000)
plt.show()

# %%
#for LATENCY valence by session effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

#x=['Ketamine','Placebo']
#neg=[0.146, 0.1489]
#pos=[.1494, 0.1469]
#neg_err=[0.001255, 0.001165]
#pos_err=[0.001196, 0.001187]
x=['Placebo','Ketamine']
neg=[0.1489,0.146]
pos=[0.1469,.1494]
neg_err=[0.001165,0.001255]
pos_err=[0.001187,0.001196]
neg_plt=plt.plot(neg, label="Neg",color='steelblue')
pos_plt=plt.plot(pos, label="Pos", color='orange')
plt.rcParams["figure.figsize"]=[6,5]
plt.title('Left Fusiform Valence by Session', fontsize='18')
plt.xlabel('Session', fontsize=14, labelpad=None)
plt.ylabel('Latency', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
plt.errorbar(x,neg,yerr=neg_err, color='steelblue',capsize=10,markeredgewidth=3)
plt.errorbar(x,pos,yerr=pos_err, color='orange',capsize=10,markeredgewidth=3)
plt.legend(loc='lower center',frameon=True)
plt.tight_layout()
plt.autoscale()
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/LeftFusiform_ValencebySess_Latency.eps',format='eps', dpi=1000)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LFus_Valence_Session_Latency_KETPLC.png',format='png', dpi=1000)
plt.show()

# %%
#for LATENCY diagnoses by valence effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

x=['Negative','Positive']
hc=[0.1486, 0.1476]
mdd=[0.1462, 0.1487]
hc_err=[0.00143, 0.001356]
mdd_err=[0.00133, 0.00126]
hc_plt=plt.plot(hc, label="HC",color='orange')
mdd_plt=plt.plot(mdd, label="MDD", color='blue')
plt.rcParams["figure.figsize"]=[6,5]
plt.title('Left Fusiform Latency DX by Valence', fontsize='18')
plt.xlabel('Valence', fontsize=14, labelpad=None)
plt.ylabel('Latency', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
plt.errorbar(x,hc,yerr=hc_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,mdd,yerr=mdd_err,fmt='b',color='b',capsize=10,markeredgewidth=3)
plt.legend(loc='lower center',frameon=True)
plt.autoscale()
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LFus_DX_Sesion_Latency_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/LeftFusiform_DX_Valence_Latency.eps',format='eps', dpi=1000, bbox_inches = "tight")
plt.show()

# %%
#for PEAK diagnoses by session effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

x=['Ketamine','Placebo']
hc=[0.3754, 0.2477]
mdd=[.1267, 0.486]
hc_err=[0.1303, 0.1283]
mdd_err=[0.1205, 0.1211]
hc_plt=plt.plot(hc, label="HC",color='orange')
mdd_plt=plt.plot(mdd, label="MDD", color='blue')
plt.rcParams["figure.figsize"]=[6,5]
plt.title('Right Fusiform Peak Negative Stimuli', fontsize='14')
plt.xlabel('Session', fontsize=14, labelpad=None)
plt.ylabel('Peak', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
plt.errorbar(x,hc,yerr=hc_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,mdd,yerr=mdd_err,fmt='b',color='b',capsize=10,markeredgewidth=3)
plt.legend(loc='lower right',frameon=True)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/RFus_Negative_DXSess_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/RFus_Neg_DXbySess.eps',format='eps', dpi=1000)
plt.show()

# %%
#for PEAK diagnoses by session effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

x=['Ketamine','Placebo']
hc=[0.3713, 0.3237]
mdd=[.2804, 0.4418]
hc_err=[0.1375, 0.1129]
mdd_err=[0.1256, 0.106]
hc_plt=plt.plot(hc, label="HC",color='orange')
mdd_plt=plt.plot(mdd, label="MDD", color='blue')
plt.rcParams["figure.figsize"]=[6,5]
plt.title('Right Fusiform Peak Positive Stimuli', fontsize='14')
plt.xlabel('Session', fontsize=14, labelpad=None)
plt.ylabel('Peak', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
axes = plt.gca()
axes.set_ylim([0,.6])
plt.errorbar(x,hc,yerr=hc_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,mdd,yerr=mdd_err,fmt='b',color='b',capsize=10,markeredgewidth=3)
plt.legend(loc='lower right',frameon=True)
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/RFus_Positive_DXSess_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/RFus_Pos_DXbySess.eps',format='eps', dpi=1000)
plt.show()

# %%
#for PEAK diagnoses effect  
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 

# Create lists for the plot
diagnoses = ['HC', 'MDD']
HC=.1539
MDD=.5175
HC_err=.09257
MDD_err=.08375
x_pos = np.arange(len(diagnoses))
effects = [HC,MDD]
error = [HC_err,MDD_err]

fig, ax = plt.subplots()
ax.bar(x_pos, effects, yerr=error, align='center', color = ['orange','steelblue'], ecolor='black', capsize=10)
#ax.bar(x_pos, effects, yerr=error, align='center', color = ['orange','blue'], alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Peak', fontsize='14')
plt.rcParams["figure.figsize"]=[5,5]
ax.set_xticks(x_pos)
ax.set_xticklabels(diagnoses, fontsize='14')
ax.set_title('Left Mid Occipital Peak by DX', fontsize='18')
ax.yaxis.grid(False)
plt.tick_params(labelsize=13)
# Save the figure and show

plt.autoscale()
plt.tight_layout()
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LMidOcc_Diagnoses_Bar_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/LMidOccDXBar.eps')
plt.show()

# %%
#for PEAK diagnoses effect  
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style
import numpy as np 

# Create lists for the plot
valence = ['Negative', 'Positive']
Neg=.6768
Pos=.5785
Neg_err=.07863
Pos_err=.08484
x_pos = np.arange(len(diagnoses))
effects = [Neg,Pos]
error = [Neg_err,Pos_err]

fig, ax = plt.subplots()
ax.bar(x_pos, effects, yerr=error, align='center', color = ['dodgerblue','orange'], ecolor='black', capsize=10)
#ax.bar(x_pos, effects, yerr=error, align='center', color = ['dodgerblue','orangered'], ecolor='black', capsize=10)
ax.set_ylabel('Peak')
plt.rcParams["figure.figsize"]=[5,5]
ax.set_xticks(x_pos)
ax.set_xticklabels(valence)
ax.set_title('Right Mid Occipital Difference by Valence', fontsize='14')
ax.yaxis.grid(False)
# Save the figure and show
plt.tight_layout()
plt.autoscale()
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/RMidOcc_Valence_Bar_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/RightMidOccValenceBar.eps')
plt.show()

# %%
#for PEAK diagnoses effect  
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style
import numpy as np 

# Create lists for the plot
session = ['Placebo', 'Ketamine']
PLC=.09041
KET=.3128
PLC_err=.08972
KET_err=.08703

x_pos = np.arange(len(session))
effects = [PLC,KET]
error = [PLC_err,KET_err]

fig, ax = plt.subplots()
ax.bar(x_pos, effects, yerr=error, align='center', color = ['steelblue','orange'], ecolor='black', capsize=10)

#ax.bar(x_pos, effects, yerr=error, align='center', color = ['deepskyblue','gold'], ecolor='black', capsize=10)
ax.set_ylabel('Peak', fontsize='14')
plt.rcParams["figure.figsize"]=[5,6]
ax.set_xticks(x_pos)

ax.set_xticklabels(session, fontsize='14')
ax.set_title('Left Fusiform Peak by Session', fontsize='18')
ax.yaxis.grid(False)
# Save the figure and show
#plt.tight_layout()
plt.rcParams["figure.figsize"]=[5,5]
plt.tick_params(labelsize=13)
plt.tight_layout()
plt.autoscale()
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/LFus_Session_Bar_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/LeftFusiformSessionBar.eps')
plt.show()

# %%
#for PEAK diagnoses by session effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

x=['HC','MDD']
KET=[.3754,.1267]
PLC=[.2477, 0.486]
KET_err=[0.1303, 0.1205]
PLC_err=[0.1283, 0.1211]
KET_plt=plt.plot(KET, label="KET",color='orange')
PLC_plt=plt.plot(PLC, label="PLC", color='steelblue')
plt.rcParams["figure.figsize"]=[5,6]
plt.title('Right Fusiform - Negative Stimuli', fontsize='18')
plt.xlabel('Session', fontsize=14, labelpad=None)
plt.ylabel('Peak', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
plt.errorbar(x,KET,yerr=KET_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,PLC,yerr=PLC_err,color='steelblue',capsize=10,markeredgewidth=3)
plt.legend(loc='lower center',frameon=True)
#plt.autoscale()
plt.rcParams["figure.figsize"]=[6,5]
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/2RFus_Negative_DXSess_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/RFus_Neg_DXbySess.eps',format='eps', dpi=1000)
plt.show()

# %%
#for PEAK diagnoses by session effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

x=['HC','MDD']
KET=[.3713,.2804]
PLC=[.3237, 0.4418]
KET_err=[0.1375, 0.1256]
PLC_err=[0.1129, 0.106]
KET_plt=plt.plot(KET, label="KET",color='orange')
PLC_plt=plt.plot(PLC, label="PLC", color='steelblue')
plt.rcParams["figure.figsize"]=[6,5]
plt.title('Right Fusiform - Positive Stimuli', fontsize='18')
plt.xlabel('Session', fontsize=14, labelpad=None)
plt.ylabel('Peak', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
plt.errorbar(x,KET,yerr=KET_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,PLC,yerr=PLC_err, color='steelblue',capsize=10,markeredgewidth=3)
plt.legend(loc='lower center',frameon=True)
plt.autoscale()
axes = plt.gca()
axes.set_ylim([0,.6])
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/2RFus_Positive_DXSess_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/RFus_Neg_DXbySess.eps',format='eps', dpi=1000)
plt.show()

# %%
#for PEAK diagnoses by session effects 
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.style as style

x=['HC','MDD']
KET=[.3754,.1267]
PLC=[.2477, 0.486]
KET_err=[0.1303, 0.1205]
PLC_err=[0.1283, 0.1211]

KET_plt=plt.plot(KET, label="KET",color='orange')
PLC_plt=plt.plot(PLC, label="PLC", color = 'steelblue')
plt.rcParams["figure.figsize"]=[6,5]
plt.title('Right Fusiform - Negative Stimuli', fontsize='18')
plt.xlabel('Session', fontsize=14, labelpad=None)
plt.ylabel('Peak', fontsize=14, labelpad=None)
plt.tick_params(labelsize=13)
axes = plt.gca()
axes.set_ylim([0,.6])
plt.errorbar(x,KET,yerr=KET_err, color='orange',capsize=10,markeredgewidth=3)
plt.errorbar(x,PLC,yerr=PLC_err,color='steelblue',capsize=10,markeredgewidth=3)
plt.legend(loc='lower center',frameon=True)
plt.autoscale()
plt.savefig('/home/sepeforrestl2/EmoEvalGraphs/2RFus_Negative_DXSess_KETPLC.png',format='png', dpi=1000)
#plt.savefig('/Users/sepeforrestl2/Downloads/EmoEval/Graphs/RFus_Neg_DXbySess.eps',format='eps', dpi=1000)
plt.show()
